# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhiraunak06/AI-Query-Tube/blob/main/Abhishek/AI_Query_Tube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests pandas

# %%
import requests
import pandas as pd

API_KEY = "AIzaSyCOYxp0CywxmWTnnQmu7JZ3stYrcpbxH3A"
CHANNEL_ID = "UCM-yUTYGmrNvKOCcAl21g3w"

# %%
url = "https://www.googleapis.com/youtube/v3/search"
params = {
    "key": API_KEY,
    "channelId": CHANNEL_ID,
    "part": "snippet,id",
    "order": "date",
    "maxResults": 50
}

response = requests.get(url, params=params).json()

videos = []
for item in response["items"]:
    if "videoId" in item["id"]:
        video_id = item["id"]["videoId"]
        title = item["snippet"]["title"]
        published = item["snippet"]["publishedAt"]
        videos.append([video_id, title, published])

df = pd.DataFrame(videos, columns=["video_id", "title", "published_date"])
df.head()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Joshika-Mentor/AI-Query-Tube.git
# Out:
# Cloning into 'AI-Query-Tube'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 67 (delta 20), reused 4 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (67/67), 58.61 KiB | 2.44 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# %cd AI-Query-Tube
# Out:
# /content/AI-Query-Tube

# %%
# !git checkout Abhishek-kumar-Raunak
# Out:
# Branch 'Abhishek-kumar-Raunak' set up to track remote branch 'Abhishek-kumar-Raunak' from 'origin'.
# Switched to a new branch 'Abhishek-kumar-Raunak'

# %%
# !git fetch
# !git checkout Abhishek-kumar-Raunak
# Out:
# Already on 'Abhishek-kumar-Raunak'
# Your branch is up to date with 'origin/Abhishek-kumar-Raunak'.

# %%
# !git status
# Out:
# On branch Abhishek-kumar-Raunak
# Your branch is up to date with 'origin/Abhishek-kumar-Raunak'.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m "Added code from Colab"
# Out:
# On branch Abhishek-kumar-Raunak
# Your branch is up to date with 'origin/Abhishek-kumar-Raunak'.
#
# nothing to commit, working tree clean

# %%
# !git config --global user.email "shiningabhi06@gmail.com"
# !git config --global user.name "Abhishek kumar Raunak"

# %%
# !git push origin Abhishek-kumar-Raunak
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
df.to_csv("youtube_metadata.csv", index=False)
